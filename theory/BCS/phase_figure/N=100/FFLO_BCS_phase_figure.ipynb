# %%
import numpy as np
from numpy import *
import matplotlib.pyplot as plt
from time import time
#from scipy.integrate import quad

print(time())

## gap_eq をdef

def e_k_spin(k1, k2, q, y, B): 
    return 2*t*(np.cos(a*(k1+q/2))+np.cos(a*(k2))) - u + y * 1/2 * gu * B

def e_k_s(k1, k2, q, B):
    return (e_k_spin(k1, k2, q, 1, B) + e_k_spin(-1*k1, k2, q, -1, B))/2

def e_k_a(k1, k2, q, B):
    return (e_k_spin(k1, k2, q, 1, B) - e_k_spin(-1*k1, k2, q, -1, B))/2

def E_k_q(k1, k2, gap, q, B):
    return np.sqrt(e_k_s(k1, k2, q, B)**2 + gap**2)

def E_k_q_s(k1, k2, gap, q, y, B):
    return E_k_q(k1, k2, gap, q, B) + y * e_k_a(k1, k2, q, B)

def Fermi(beta, E):
    return 1 / (np.exp(beta*E) + 1 )

def func(k1, k2, gap, q, B): 
    return gap*(1-Fermi(beta, E_k_q_s(k1, k2, gap, q, -1, B))-Fermi(beta, E_k_q_s(k1, k2, gap, q, 1, B)))/(2*E_k_q(k1, k2, gap, q, B))

def rhs(gap, q, B):
    k1 = -1 * np.pi/a + 2 * arange(N) * np.pi / (a * N)
    kx, ky = meshgrid(k1, k1, indexing='ij')
    f = func(kx, ky, gap, q, B)
    return (V / (N**2)) * sum(f)

print(time())

##パラメータの調整
N, V, t, a, u, gu, n0, n1, n2 =100, 1, 1, 1, 3, 1, 90, 50, 50    # 7.525 #9.21
qs   = np.linspace(0,0.1,n0)  #(np.pi/a)
Bs   = np.linspace(0.1,0.15,n1)     #np.linspace(0,0.08,n1)
kBTs = np.linspace(1e-5,0.05,n2)



print(time())

##ギャップの逐次計算
# 各温度、各磁場において、重心運動量qごとにギャップを記録する
# ans[h][i][j][0] で各重心運動量,各磁場、各温度において記録する
ans = []
for h in range(n2):
    ans0 = []
    for i in range(n1):
        ans1 = []
        for j in range(n0): # それぞれの温度で秩序パラメータを計算
            beta, d0 = 1/kBTs[h], 100.0
            for k in range(1000): # 収束するまで最大1000回ループ
                d1 = rhs(d0, qs[j], Bs[i]) 
                if abs(d1-d0) < 1e-10: break # 収束チェック
                d0 = d1
            ans1.append(d0)
        ans0.append(ans1)
    ans.append(ans0)
ans = np.array(ans)

print(time())
print(ans)

##ギャップの逐次計算
# 各温度、各磁場において、重心運動量qごとにギャップを記録する
# ans[h][i][j][0] で各重心運動量,各磁場、各温度において記録する
ans = []
for h in range(n2):
    ans0 = []
    for i in range(n1):
        ans1 = []
        for j in range(n0): # それぞれの温度で秩序パラメータを計算
            beta, d0 = 1/kBTs[h], 100.0
            for k in range(1000): # 収束するまで最大1000回ループ
                d1 = rhs(d0, qs[j], Bs[i]) 
                if abs(d1-d0) < 1e-10: break # 収束チェック
                d0 = d1
            ans1.append(round(d0,4))
        ans0.append(ans1)
    ans.append(ans0)
ans = np.array(ans)

print(time())
print(ans)

# 重心運動量qごとにもっともギャップの立ちやすいqを取り出す

ans_h = []
ans_i = []
q_max_1 = []
for h in range(n2):
    q_max_2 = []
    ans_h = ans[h]
    for i in range(n1):
        ans_i = ans_h[i]
        ans_l = ans_i.tolist()
        max_q = float(max(ans_i))
        if max_q < 0.0001: 
            max_index = 0
        else:
            max_index = ans_l.index(max_q)
        # print(ans_i)
        # print(max_q)
        q_max_2.append(max_index)
    q_max_1.append(q_max_2)
q_max_1 = np.array(q_max_1)
print(q_max_1)

# q=0をBCSへq＝＼0をFFLOへと色分けする
for h in range(n2):
    for i in range(n1):
            figure = plt.scatter(kBTs[h], Bs[i], 5, c = q_max_1[h][i], cmap='viridis' ,vmin=0, vmax=n0) # c = q_max[h][i]
c= plt.colorbar()
plt.savefig("FFLO_BCS_phase_figure.png")
plt.show()
# Out:
# 1687759767.0530329
# 1687759767.053386
# 1687759767.0535371
# /var/folders/vf/842hmrqn18z65j0fs1m3p8200000gn/T/ipykernel_75138/3369486909.py:27: RuntimeWarning: overflow encountered in exp
#   return 1 / (np.exp(beta*E) + 1 )
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 61
#      59 beta, d0 = 1/kBTs[h], 100.0
#      60 for k in range(1000): # 収束するまで最大1000回ループ
# ---> 61     d1 = rhs(d0, qs[j], Bs[i])
#      62     if abs(d1-d0) < 1e-10: break # 収束チェック
#      63     d0 = d1
#
# Cell In[1], line 35, in rhs(gap, q, B)
#      33 k1 = -1 * np.pi/a + 2 * arange(N) * np.pi / (a * N)
#      34 kx, ky = meshgrid(k1, k1, indexing='ij')
# ---> 35 f = func(kx, ky, gap, q, B)
#      36 return (V / (N**2)) * sum(f)
#
# Cell In[1], line 30, in func(k1, k2, gap, q, B)
#      29 def func(k1, k2, gap, q, B):
# ---> 30     return gap*(1-Fermi(beta, E_k_q_s(k1, k2, gap, q, -1, B))-Fermi(beta, E_k_q_s(k1, k2, gap, q, 1, B)))/(2*E_k_q(k1, k2, gap, q, B))
#
# Cell In[1], line 24, in E_k_q_s(k1, k2, gap, q, y, B)
#      23 def E_k_q_s(k1, k2, gap, q, y, B):
# ---> 24     return E_k_q(k1, k2, gap, q, B) + y * e_k_a(k1, k2, q, B)
#
# Cell In[1], line 18, in e_k_a(k1, k2, q, B)
#      17 def e_k_a(k1, k2, q, B):
# ---> 18     return (e_k_spin(k1, k2, q, 1, B) - e_k_spin(-1*k1, k2, q, -1, B))/2
#
# KeyboardInterrupt:

# %%
ans= [[[1.20568841e-10 ,1.22939962e-10]
  ,[1.20568841e-10 ,1.22939962e-10]]

 ,[[1.19148623e-10, 1.20953588e-10]
  ,[1.18385584e-10, 1.19892282e-10]]]

q_max = []
for h in range(2):
    for i in range(2):
        max_q    = max(ans[h][i])
        print(ans[h][i])
        print(max_q)
        print(ans[h][i].index(max_q))
        q_max.append(max_index)
# Out:
# [1.20568841e-10, 1.22939962e-10]
# 1.22939962e-10
# 1
# [1.20568841e-10, 1.22939962e-10]
# 1.22939962e-10
# 1
# [1.19148623e-10, 1.20953588e-10]
# 1.20953588e-10
# 1
# [1.18385584e-10, 1.19892282e-10]
# 1.19892282e-10
# 1

# %%
sample_list = [
    [[134, 245667, 45673],[59833444,234565, 789477],[544, 23, 747333333337]],
    [[12, 2467, 4578673],[5444,4565, 77],[367, 98, 33333333]],
    [[1334, 12667, 453],[59834,2365, 7477],[14, 55, 766667]]
    ]
print(sample_list)
 
print('・3次元リストの最大値を取得する')
sample_list_max1 = max(sample_list)
print(sample_list_max1)
 
print('・3次元リスト内の2次元リスト最大値を取得する')
sample_list_max2 = max(sample_list[1])
print(sample_list_max2)
 
print('・3次元リスト内の1次元リスト最大値を取得する')
sample_list_max3 = max(sample_list[2][2])
print(sample_list_max3)

print(sample_list[2][2].index(sample_list_max3))
# Out:
# [[[134, 245667, 45673], [59833444, 234565, 789477], [544, 23, 747333333337]], [[12, 2467, 4578673], [5444, 4565, 77], [367, 98, 33333333]], [[1334, 12667, 453], [59834, 2365, 7477], [14, 55, 766667]]]
# ・3次元リストの最大値を取得する
# [[1334, 12667, 453], [59834, 2365, 7477], [14, 55, 766667]]
# ・3次元リスト内の2次元リスト最大値を取得する
# [5444, 4565, 77]
# ・3次元リスト内の1次元リスト最大値を取得する
# 766667
# 2
